# %%
import requests
import simplejson as json
import pandas as pd
import numpy as np
import os
import json

# %%
notebook_path = os.path.abspath("OLS matching.ipynb")
config_path = os.path.join(os.path.dirname(notebook_path), "Data/config0.json")

# %%
with open(config_path) as config_file:
    config= json.load(config_file)
config
# Out:
# {'asctb_sid': '1tK916JyG5ZSXW_cXfsyZnzXfjyoN-8B2GXLbYD6_vF0',
#  'references': [{'name': 'lung',
#    'url': 'https://hubmapconsortium.github.io/asctb-azimuth-data-comparison/lung.csv',
#    'organ_name': 'lung',
#    'asctb_sheet_name': 'Lung_v.1.1'},
#   {'name': 'pancreas',
#    'url': 'https://hubmapconsortium.github.io/asctb-azimuth-data-comparison/pancreas.csv',
#    'organ_name': 'pancreas',
#    'asctb_sheet_name': 'Pancreas_v1.0'},
#   {'name': 'kidney',
#    'url': 'https://hubmapconsortium.github.io/asctb-azimuth-data-comparison/kidney.csv',
#    'organ_name': 'kidney',
#    'asctb_sheet_name': 'Kidney_v1.1'},
#   {'name': 'brain',
#    'url': 'https://hubmapconsortium.github.io/asctb-azimuth-data-comparison/motor_cortex.csv',
#    'organ_name': 'brain',
#    'asctb_sheet_name': 'Brain_v1.1'},
#   {'name': 'bone_marrow',
#    'url': 'https://hubmapconsortium.github.io/asctb-azimuth-data-comparison/bone_marrow.csv',
#    'organ_name': 'bone_marrow',
# ...

# %%
asctb_sid = config["asctb_sid"]
# Out:
# '1tK916JyG5ZSXW_cXfsyZnzXfjyoN-8B2GXLbYD6_vF0'

# %%
sheet_id = '1tK916JyG5ZSXW_cXfsyZnzXfjyoN-8B2GXLbYD6_vF0'
sheet_name="Kidney_v1.1"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

a=pd.read_csv(url,skiprows=3)
a
# Out:
#       AS/1 AS/1/LABEL         AS/1/ID              AS/2           AS/2/LABEL  \
# 0   kidney     kidney  UBERON:0002113    kidney capsule       kidney capsule
# 1   kidney     kidney  UBERON:0002113  cortex of kidney     cortex of kidney
# 2   kidney     kidney  UBERON:0002113  cortex of kidney     cortex of kidney
# 3   kidney     kidney  UBERON:0002113  cortex of kidney     cortex of kidney
# 4   kidney     kidney  UBERON:0002113     renal medulla        renal medulla
# ..     ...        ...             ...               ...                  ...
# 72  kidney     kidney  UBERON:0002113      Interstitium  kidney interstitium
# 73  kidney     kidney  UBERON:0002113      Interstitium  kidney interstitium
# 74  kidney     kidney  UBERON:0002113      Interstitium  kidney interstitium
# 75  kidney     kidney  UBERON:0002113      Interstitium  kidney interstitium
# 76  kidney     kidney  UBERON:0002113      Interstitium  kidney interstitium
#
# ...
